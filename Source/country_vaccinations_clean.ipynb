# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("country_vaccinations.csv")
print(df.head())
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2/22/2021                 0.0                0.0
# 1  Afghanistan      AFG  2/23/2021                 NaN                NaN
# 2  Afghanistan      AFG  2/24/2021                 NaN                NaN
# 3  Afghanistan      AFG  2/25/2021                 NaN                NaN
# 4  Afghanistan      AFG  2/26/2021                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
df.shape
# Out:
# (25862, 15)

# %%
df.tail()
# Out:
#         country iso_code       date  total_vaccinations  people_vaccinated  \
# 25857  Zimbabwe      ZWE  6/16/2021           1120873.0           697399.0
# 25858  Zimbabwe      ZWE  6/17/2021           1126087.0           698953.0
# 25859  Zimbabwe      ZWE  6/18/2021           1131397.0           700244.0
# 25860  Zimbabwe      ZWE  6/19/2021           1133920.0           701348.0
# 25861  Zimbabwe      ZWE  6/20/2021           1138733.0           703065.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 25857                 423474.0                  7395.0              5270.0
# 25858                 427134.0                  5214.0              5226.0
# 25859                 431153.0                  5310.0              4935.0
# 25860                 432572.0                  2523.0              4360.0
# 25861                 435668.0                  4813.0              4525.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25862 entries, 0 to 25861
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              25862 non-null  object
#  1   iso_code                             25862 non-null  object
#  2   date                                 25862 non-null  object
#  3   total_vaccinations                   14522 non-null  float64
#  4   people_vaccinated                    13762 non-null  float64
#  5   people_fully_vaccinated              11041 non-null  float64
#  6   daily_vaccinations_raw               12003 non-null  float64
#  7   daily_vaccinations                   25595 non-null  float64
#  8   total_vaccinations_per_hundred       14522 non-null  float64
#  9   people_vaccinated_per_hundred        13762 non-null  float64
#  10  people_fully_vaccinated_per_hundred  11041 non-null  float64
# ...

# %%
df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        1.452200e+04       1.376200e+04             1.104100e+04
# mean         9.139252e+06       4.737802e+06             2.681353e+06
# std          4.592776e+07       1.797156e+07             1.093032e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          1.005620e+05       7.876700e+04             3.719700e+04
# 50%          7.007560e+05       5.149065e+05             2.834740e+05
# 75%          3.241681e+06       2.139073e+06             1.192415e+06
# max          1.029223e+09       6.220000e+08             2.232990e+08
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            1.200300e+04        2.559500e+04
# mean             2.012910e+05        1.020430e+05
# std              1.122962e+06        7.304361e+05
# min              0.000000e+00        0.000000e+00
# 25%              3.967500e+03        8.400000e+02
# ...

# %%
df.describe(include='object')
# Out:
#        country iso_code       date            vaccines         source_name  \
# count    25862    25862      25862               25862               25862
# unique     217      217        201                  56                  95
# top     Norway      NOR  5/12/2021  Oxford/AstraZeneca  Ministry of Health
# freq       201      201        207                4326                6732
#
#                   source_website
# count                      25862
# unique                       150
# top     https://covid19.who.int/
# freq                        4324

# %%
df['date'] = pd.to_datetime(df['date'])
df['date'].dtype
print(df['date'].min())
print(df['date'].max())
# Out:
# 2020-12-02 00:00:00
# 2021-06-20 00:00:00

# %%
df.isnull().sum()
# Out:
# country                                    0
# iso_code                                   0
# date                                       0
# total_vaccinations                     11340
# people_vaccinated                      12100
# people_fully_vaccinated                14821
# daily_vaccinations_raw                 13859
# daily_vaccinations                       267
# total_vaccinations_per_hundred         11340
# people_vaccinated_per_hundred          12100
# people_fully_vaccinated_per_hundred    14821
# daily_vaccinations_per_million           267
# vaccines                                   0
# source_name                                0
# source_website                             0
# dtype: int64

# %%
df.isnull().mean() * 100 ##Tỷ lệ missing
# Out:
# country                                 0.000000
# iso_code                                0.000000
# date                                    0.000000
# total_vaccinations                     43.848117
# people_vaccinated                      46.786791
# people_fully_vaccinated                57.308019
# daily_vaccinations_raw                 53.588276
# daily_vaccinations                      1.032403
# total_vaccinations_per_hundred         43.848117
# people_vaccinated_per_hundred          46.786791
# people_fully_vaccinated_per_hundred    57.308019
# daily_vaccinations_per_million          1.032403
# vaccines                                0.000000
# source_name                             0.000000
# source_website                          0.000000
# dtype: float64

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# people_fully_vaccinated                14821
# people_fully_vaccinated_per_hundred    14821
# daily_vaccinations_raw                 13859
# people_vaccinated_per_hundred          12100
# people_vaccinated                      12100
# total_vaccinations                     11340
# total_vaccinations_per_hundred         11340
# daily_vaccinations_per_million           267
# daily_vaccinations                       267
# date                                       0
# country                                    0
# iso_code                                   0
# vaccines                                   0
# source_name                                0
# source_website                             0
# dtype: int64

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['country', 'iso_code', 'vaccines', 'source_name', 'source_website'], dtype='object')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['vaccines'].value_counts()
# Out:
# vaccines
# Oxford/AstraZeneca                                                                             4326
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                                  3437
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                                                   2222
# Oxford/AstraZeneca, Pfizer/BioNTech                                                            1697
# Moderna, Pfizer/BioNTech                                                                       1394
# Pfizer/BioNTech                                                                                1143
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V                              1122
# Oxford/AstraZeneca, Sinopharm/Beijing                                                          1082
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac                                                   1033
# ...

# %%
df = df.dropna()

# %%
print(df.isna().sum())
# Out:
# country                                0
# iso_code                               0
# date                                   0
# total_vaccinations                     0
# people_vaccinated                      0
# people_fully_vaccinated                0
# daily_vaccinations_raw                 0
# daily_vaccinations                     0
# total_vaccinations_per_hundred         0
# people_vaccinated_per_hundred          0
# people_fully_vaccinated_per_hundred    0
# daily_vaccinations_per_million         0
# vaccines                               0
# source_name                            0
# source_website                         0
# dtype: int64

# %%
df.to_csv("country_vaccinations_cleaned.csv", index=False)
print("Xuất file thành công")
# Out:
# Xuất file thành công

# %%
df_manufacture = pd.read_csv('country_vaccinations_by_manufacturer.csv')
df_manufacture.head(10)
# Out:
#   location       date        vaccine_name  total_vaccinations
# 0  Austria   1/5/2021     Johnson&Johnson                   0
# 1  Austria   1/5/2021             Moderna                   0
# 2  Austria   1/5/2021  Oxford/AstraZeneca                   0
# 3  Austria   1/5/2021     Pfizer/BioNTech               30885
# 4  Austria  1/12/2021     Johnson&Johnson                   0
# 5  Austria  1/12/2021             Moderna                  88
# 6  Austria  1/12/2021  Oxford/AstraZeneca                   0
# 7  Austria  1/12/2021     Pfizer/BioNTech              115203
# 8  Austria  1/19/2021     Johnson&Johnson                   0
# 9  Austria  1/19/2021             Moderna                 298

# %%
df_manufacture.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7517 entries, 0 to 7516
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   location            7517 non-null   object
#  1   date                7517 non-null   datetime64[ns]
#  2   vaccine_name        7517 non-null   object
#  3   total_vaccinations  7517 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 235.0+ KB

# %%
df_manufacture['date'] = pd.to_datetime(df_manufacture['date'])
df_manufacture['date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
print(df_manufacture['date'].min())
print(df_manufacture['date'].max())
# Out:
# 2020-12-24 00:00:00
# 2021-06-21 00:00:00

# %%
df_manufacture.isna().sum()
# Out:
# location              0
# date                  0
# vaccine_name          0
# total_vaccinations    0
# dtype: int64

# %%
df_manufacture.dtypes
# Out:
# location                      object
# date                  datetime64[ns]
# vaccine_name                  object
# total_vaccinations             int64
# dtype: object
